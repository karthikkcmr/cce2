# %%
listP = [200, 500, 950, 30]
listD = [500, 3500, 5450, 90]
def payment(plan):
    print("Amount to be paid = ",listP[plan])
    print("Mode fo payments available : ")
    print("1. Online Transfer 2. UPI apps")
    pay = int(input("Enter your choice : "))
    if pay == 1 : 
        print("Enter your Card Details here : ")
        print("Enter CVV : ")
        print("Initiating Transaction please wait...")
        print("RECHARGE DONE. Thank you!")
    elif pay == 2:
        print("1. Google Pay ")
        print("2. Phone Pay ")
        print("3. PayTM")
        print()
        print("**********QR CODE*************")
        print()
        print("Initiating Transaction please wait...")
        print("RECHARGE DONE. Thank you!")
    else:
        print("There was an error during transaction process... please try again after some time")
        print("Thank you!")
    return

def airtel():
    print("____AIRTEl____")
    print("1. Recharge 2. Coupons 3. Subscriptions")
    choice = int(input("Enter your choice : "))
    if choice == 1 :
        print("1. Unlimited Talktime 2. Unlimited Data ")
        print()
        ch = int(input("Enter your choice to view available plans : "))
        if ch == 1:
            #listP = [200, 500, 950, 30]
            print("1. Monthly...............200")
            print("2. 6 months..............500")
            print("3. Year..................950")
            print("4. 15 days................30")
            plan = int(input("Enter your plan : "))
            payment(plan-1)
        elif ch == 2 :
            print("1. Monthly...............500")
            print("2. 6 months..............3500")
            print("3. Year..................5450")
            print("4. 15 days................90")
            plan = int(input("Enter your plan : "))
            payment(plan-1)  
        else:
            print("No plans available with your choice")
            print()
    elif choice == 2:
        print("--------------Your coupons are ------------ ")
        print("Recharge for Rs. 200 get a dicount of Rs. 8")
        print("Recharge for Rs. 500 get a dicount of Rs. 48")
    elif choice == 3:
        print("---------Subscriptions on Airtel--------- ")
        print("### Offer ###Subsription packages added to the user when recharged for special packages")
        print("Airtel Live Tv ")
        print("Airtel XStream")
    else :
        print(error)  
    return

def jio():
    print("____JIO____")
    print("1. Recharge 2. Coupons 3. Subscriptions")
    choice = int(input("Enter your choice : "))
    if choice == 1 :
        print("1. Unlimited Talktime 2. Unlimited Data ")
        print()
        ch = int(input("Enter your choice to view available plans : "))
        if ch == 1:
            #listP = [200, 500, 950, 30]
            print("1. Monthly...............200")
            print("2. 6 months..............500")
            print("3. Year..................950")
            print("4. 15 days................30")
            plan = int(input("Enter your plan : "))
            payment(plan-1)
        elif ch == 2 :
            print("1. Monthly...............500")
            print("2. 6 months..............3500")
            print("3. Year..................5450")
            print("4. 15 days................90")
            plan = int(input("Enter your plan : "))
            payment(plan-1) 
        else:
            print("No plans available with your choice")
    elif choice == 2:
        print("--------------Your coupons are ------------ ")
        print("Recharge for Rs. 200 get a dicount of Rs. 8")
        print("Recharge for Rs. 500 get a dicount of Rs. 48")
    elif choice == 3:
        print("---------Subscriptions on Airtel--------- ")
        print("### Offer ###Subsription packages added to the user when recharged for special packages")
        print("Airtel Live Tv ")
        print("Airtel XStream")
    else :
        print(error)  

    return
 
print("Recharge Plans")
print("Services : 1. Airtel 2. Jio")
service = int(input("Enter the name of your service provider : "))
if service ==1 : 
    airtel()
elif service == 2 :
    jio()
else:
    print("We do not provide your requested serivice. Thank you! Visit us again...")
# Out:
# Recharge Plans
# Services : 1. Airtel 2. Jio
# Enter the name of your service provider : 1
# ____AIRTEl____
# 1. Recharge 2. Coupons 3. Subscriptions
# Enter your choice : 2
# --------------Your coupons are ------------
# Recharge for Rs. 200 get a dicount of Rs. 8
# Recharge for Rs. 500 get a dicount of Rs. 48
