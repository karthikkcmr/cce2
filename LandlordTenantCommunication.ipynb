# %%
listApp = [1, 2, 4];
def appointment():
 print("Appointment timings : ")
 print("1. 10 AM to 11 AM")
 print("2. 11 AM to 12 PM")
 print("3. 12 AM to 1 PM")
 print("4. 1 PM to 2 PM")
 print("5. 2 PM to 3 PM")
 print("Available time slots as of now : ")
 for i in range(10, 4):
     if listApp[i] != i:
         print(i," ") 
 time = int(input("Enter your choice to schdule your tour : "))
 if time >=1 and time <= 5 : 
     listApp.append(time)
     print("Thank you! Your appointment is scheduled for tomorrow at ",time,"sharp.")
 else : 
     print("The time slot you have entered is not available")
     print()
 return
 
def contact():
 print("Name : Anand Rao")
 print("Phone Number : 4365476873")
 print("Email ID : kjdsfj@gmail.com")
 print("Schdule An Appointment")
 app = input("Enter y for Yes/ Enter n for no")
 if(app == 'y'):
     appointment()
 else:
     print("Back to home")
 return
def apartments():
 print("Available apartments : ")
 print("1. 1BHK |2. 2BHK |3. 3BHK |4. 4BHK ")
 print("Do you want to take a look at the apartments?")
 lo = int(input("Enter your choice from the list of available apartments : "))
 if(lo == 1):
     print("1 bedroom, ....")
 elif lo == 2 :
     print("2 bedrooms, ....")
 elif lo == 3:
     print("3 bedrooms, ....")
 else:
     print("4 bedrooms, ....")
 return1
def online():
 print("Online payment details are : ")
 print("Account Number : sdgr35476354")
 print("IFSC code : dfgf456765")
 print("Account Holder Name : Anand Rao")
 print("Bank Branch : baglur")
 return
 
def booking():
 print("Available apartments : ")
 print("1. 1BHK |2. 2BHK |3. 3BHK |4. 4BHK ")
 type = int(input("Enter the apartment type to proceed further"))
 if(type == 1):
     amount = 4365667
 elif(type == 2):
     amount = 23465733 
 elif type == 3:
     amount = 34654768 
 elif type == 4 :
     amount = 345675434 
 else:
     print("No such apartment is available") 
 pay = int(input("Enter the mode of payment 1. online transfer or 2 to pay to the landlord"))
 if(pay == 1):
     online()
 else:
     print("Schdule an appointment and Meet the landlord to pay the amount in person")
     appointment()
 return

 
def home():
 print("Do you want to contact the owner or proceed with the available options and booking")
 print("Enter 1. To contact Landlord 2. To see availabele apartments 3. Book an apartment")
 choice = int(input("Enter your choice"))
 if choice == 1:
     contact()
 elif choice == 2 :
     apartments()
 elif choice == 3:
     booking() 
 else:
     print("Good Day")
     return
       
       
print("Apartment Name : Anjineya Complex")
print("Address : #69, Street Number 3, Vinayaka Nagar, Bangalore North 562157")
print("Owner : Arha Reddy")
print("Contct Number : 8473685567")
home()
print("Thank you for visiting us.")
# Out:
# Apartment Name : Anjineya Complex
# Address : #69, Street Number 3, Vinayaka Nagar, Bangalore North 562157
# Owner : Arha Reddy
# Contct Number : 8473685567
# Do you want to contact the owner or proceed with the available options and booking
# Enter 1. To contact Landlord 2. To see availabele apartments 3. Book an apartment
# Enter your choice3
# Available apartments :
# 1. 1BHK |2. 2BHK |3. 3BHK |4. 4BHK
# Enter the apartment type to proceed further1
# Enter the mode of payment 1. online transfer or 2 to pay to the landlord1
# Online payment details are :
# Account Number : sdgr35476354
# IFSC code : dfgf456765
# Account Holder Name : Anand Rao
# Bank Branch : baglur
# Thank you for visiting us.
